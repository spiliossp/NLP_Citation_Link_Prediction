# %% [markdown]
# # Fine Tune Node2vec Citation Directed Unweighted split train

# %%
import pandas as pd
import networkx as nx
import numpy as np
import optuna
from node2vec import Node2Vec
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
import pickle

# === 1. Load data & splits
split_path = "D:/NLP/tfidf_xgboost/split_train_val/citation_pairs_split_train_val.csv"
df = pd.read_csv(split_path)
train_df = df[df['split']=='train']
val_df   = df[df['split']=='val']

# === 2. Build weighted directed graph from positive citations only
train_pos = train_df[train_df['label']==1]
edge_weights = (
    train_pos
    .groupby(['citing','cited'])
    .size()
    .reset_index(name='weight')
)

G = nx.DiGraph()
# add all nodes (so that isolated ones are included, αν υπάρχουν)
G.add_nodes_from(pd.unique(df[['citing','cited']].values.ravel()))
for _, row in edge_weights.iterrows():
    G.add_edge(int(row['citing']), int(row['cited']))

print(f"Graph: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")

# === 3. Prepare train/val pairs + labels
train_pairs = list(zip(train_df['citing'], train_df['cited']))
train_y     = train_df['label'].tolist()

val_pairs = list(zip(val_df['citing'], val_df['cited']))
val_y     = val_df['label'].tolist()

# === 4. Define Optuna objective
def objective(trial):
    # sample hyperparams
    p      = trial.suggest_loguniform("p", 0.25, 4.0)
    q      = trial.suggest_loguniform("q", 0.25, 4.0)
    dims   = trial.suggest_categorical("dims", [64, 128, 256])
    wl     = trial.suggest_int("walk_length", 20, 100)
    nw     = trial.suggest_int("num_walks", 10, 50)
    window = trial.suggest_int("window", 5, 15)
  

    # train Node2Vec
    n2v = Node2Vec(
        G,
        dimensions=dims,
        walk_length=wl,
        num_walks=nw,
        p=p, q=q,
        weight_key='weight',
        workers=4,
        quiet=True
    )
    model = n2v.fit(window=window, min_count=1, epochs=epochs)

    # embed feature for a pair as Hadamard product
    def feat(u, v):
        vu = model.wv.get_vector(str(u))
        vv = model.wv.get_vector(str(v))
        return vu * vv

    X_train = np.vstack([feat(u, v) for u, v in train_pairs])
    X_val   = np.vstack([feat(u, v) for u, v in val_pairs])

    # simple classifier + AUC
    clf = LogisticRegression(max_iter=200)
    clf.fit(X_train, train_y)
    preds = clf.predict_proba(X_val)[:,1]
    return roc_auc_score(val_y, preds)

# === 5. Run study
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30)

print("Best AUC:", study.best_value)
print("Best params:", study.best_params)

# === 6. Train final model with best params and save embeddings
best = study.best_params
n2v_final = Node2Vec(
    G,
    dimensions=best['dims'],
    walk_length=best['walk_length'],
    num_walks=best['num_walks'],
    p=best['p'],
    q=best['q'],
    weight_key='weight',
    workers=4,
    quiet=False
)
model_final = n2v_final.fit(
    window=best['window'],
    min_count=1,
    epochs=best['epochs']
)

# extract and pickle embeddings
embeddings = {
    int(node): model_final.wv.get_vector(str(node))
    for node in G.nodes()
    if str(node) in model_final.wv
}
out_path = "D:/NLP/tfidf_xgboost/split_train_val/citation_node2vec_tuned.pkl"
with open(out_path, "wb") as f:
    pickle.dump(embeddings, f)

print(f"✅ Saved tuned embeddings to {out_path}")
# Out:
# Graph: 138499 nodes, 982760 weighted edges
# [I 2025-05-16 11:56:14,848] A new study created in memory with name: no-name-e48fa9e6-8be0-4fde-ba45-522047301e75
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 12:00:20,792] Trial 0 finished with value: 0.6768239081431762 and parameters: {'p': 0.9770158376766437, 'q': 0.9600119783631689, 'dims': 64, 'walk_length': 50, 'num_walks': 16, 'window': 13, 'epochs': 1}. Best is trial 0 with value: 0.6768239081431762.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 12:05:29,911] Trial 1 finished with value: 0.7224612559769644 and parameters: {'p': 0.5949122429295841, 'q': 3.5165434307548096, 'dims': 256, 'walk_length': 91, 'num_walks': 23, 'window': 12, 'epochs': 1}. Best is trial 1 with value: 0.7224612559769644.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 12:09:40,519] Trial 2 finished with value: 0.85872125754551 and parameters: {'p': 0.6822999660221659, 'q': 1.8004254371814423, 'dims': 64, 'walk_length': 37, 'num_walks': 14, 'window': 9, 'epochs': 4}. Best is trial 2 with value: 0.85872125754551.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 12:19:35,706] Trial 3 finished with value: 0.9321041652688503 and parameters: {'p': 3.124237154295912, 'q': 0.565057657368385, 'dims': 256, 'walk_length': 71, 'num_walks': 34, 'window': 14, 'epochs': 2}. Best is trial 3 with value: 0.9321041652688503.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 12:23:39,421] Trial 4 finished with value: 0.9275771434412303 and parameters: {'p': 0.32340696428226606, 'q': 3.257294965841052, 'dims': 128, 'walk_length': 81, 'num_walks': 24, 'window': 14, 'epochs': 3}. Best is trial 3 with value: 0.9321041652688503.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 12:29:00,513] Trial 5 finished with value: 0.9533428147727313 and parameters: {'p': 3.7282052909578525, 'q': 0.8798101286485921, 'dims': 256, 'walk_length': 68, 'num_walks': 35, 'window': 12, 'epochs': 3}. Best is trial 5 with value: 0.9533428147727313.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 12:32:40,539] Trial 6 finished with value: 0.7514653836635534 and parameters: {'p': 0.8532336775461222, 'q': 0.7833988787175831, 'dims': 128, 'walk_length': 59, 'num_walks': 27, 'window': 11, 'epochs': 1}. Best is trial 5 with value: 0.9533428147727313.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 12:36:57,565] Trial 7 finished with value: 0.8346518082394185 and parameters: {'p': 1.229446955679405, 'q': 2.9941094165346818, 'dims': 256, 'walk_length': 44, 'num_walks': 36, 'window': 11, 'epochs': 1}. Best is trial 5 with value: 0.9533428147727313.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 12:41:53,588] Trial 8 finished with value: 0.9223235392538398 and parameters: {'p': 0.48340305831078517, 'q': 0.5961124099119127, 'dims': 64, 'walk_length': 91, 'num_walks': 46, 'window': 10, 'epochs': 4}. Best is trial 5 with value: 0.9533428147727313.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 12:46:40,832] Trial 9 finished with value: 0.9373922901986946 and parameters: {'p': 2.5910128635402017, 'q': 2.42891759075802, 'dims': 64, 'walk_length': 88, 'num_walks': 49, 'window': 9, 'epochs': 3}. Best is trial 5 with value: 0.9533428147727313.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 12:53:34,319] Trial 10 finished with value: 0.9636356689059533 and parameters: {'p': 1.831887681938356, 'q': 0.28110444934045564, 'dims': 256, 'walk_length': 69, 'num_walks': 41, 'window': 5, 'epochs': 5}. Best is trial 10 with value: 0.9636356689059533.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# D:\NLP\gnn_env\lib\site-packages\joblib\externals\loky\process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [I 2025-05-16 13:00:11,842] Trial 11 finished with value: 0.9607980997461112 and parameters: {'p': 1.7253649952962302, 'q': 0.25855811618493224, 'dims': 256, 'walk_length': 22, 'num_walks': 42, 'window': 5, 'epochs': 5}. Best is trial 10 with value: 0.9636356689059533.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 13:08:12,791] Trial 12 finished with value: 0.9626477979211818 and parameters: {'p': 1.7457701803745649, 'q': 0.264694825850489, 'dims': 256, 'walk_length': 20, 'num_walks': 43, 'window': 5, 'epochs': 5}. Best is trial 10 with value: 0.9636356689059533.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 13:15:50,845] Trial 13 finished with value: 0.9628561636896839 and parameters: {'p': 1.681864968976756, 'q': 0.2629979673496977, 'dims': 256, 'walk_length': 21, 'num_walks': 42, 'window': 5, 'epochs': 5}. Best is trial 10 with value: 0.9636356689059533.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 13:22:36,989] Trial 14 finished with value: 0.9621424329237804 and parameters: {'p': 1.814856554354476, 'q': 0.4025911001768679, 'dims': 256, 'walk_length': 32, 'num_walks': 40, 'window': 7, 'epochs': 5}. Best is trial 10 with value: 0.9636356689059533.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# D:\NLP\gnn_env\lib\site-packages\joblib\externals\loky\process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [I 2025-05-16 13:29:39,139] Trial 15 finished with value: 0.9614309722667456 and parameters: {'p': 1.4974435555248327, 'q': 0.41809874804902986, 'dims': 256, 'walk_length': 56, 'num_walks': 49, 'window': 7, 'epochs': 4}. Best is trial 10 with value: 0.9636356689059533.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 13:35:15,760] Trial 16 finished with value: 0.944387731904289 and parameters: {'p': 2.428170452222163, 'q': 1.5616139692832078, 'dims': 128, 'walk_length': 72, 'num_walks': 30, 'window': 7, 'epochs': 5}. Best is trial 10 with value: 0.9636356689059533.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 13:41:01,174] Trial 17 finished with value: 0.9586133518521257 and parameters: {'p': 1.2572176922495688, 'q': 0.36077794100546845, 'dims': 256, 'walk_length': 100, 'num_walks': 37, 'window': 6, 'epochs': 4}. Best is trial 10 with value: 0.9636356689059533.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# D:\NLP\gnn_env\lib\site-packages\joblib\externals\loky\process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [I 2025-05-16 13:47:57,034] Trial 18 finished with value: 0.9613885114687991 and parameters: {'p': 2.4583404261124007, 'q': 0.30662147019532565, 'dims': 256, 'walk_length': 66, 'num_walks': 45, 'window': 8, 'epochs': 5}. Best is trial 10 with value: 0.9636356689059533.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# D:\NLP\gnn_env\lib\site-packages\joblib\externals\loky\process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [I 2025-05-16 13:52:46,041] Trial 19 finished with value: 0.9459065860331735 and parameters: {'p': 0.2691145706790381, 'q': 1.3546821389897443, 'dims': 128, 'walk_length': 31, 'num_walks': 39, 'window': 5, 'epochs': 4}. Best is trial 10 with value: 0.9636356689059533.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 13:57:11,823] Trial 20 finished with value: 0.9014904052651054 and parameters: {'p': 2.073302539241476, 'q': 0.5722118438269603, 'dims': 256, 'walk_length': 79, 'num_walks': 32, 'window': 6, 'epochs': 2}. Best is trial 10 with value: 0.9636356689059533.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 14:03:52,647] Trial 21 finished with value: 0.9638755961319057 and parameters: {'p': 1.340278589091097, 'q': 0.30263732679550054, 'dims': 256, 'walk_length': 23, 'num_walks': 44, 'window': 5, 'epochs': 5}. Best is trial 21 with value: 0.9638755961319057.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 14:10:53,157] Trial 22 finished with value: 0.9624077906023535 and parameters: {'p': 1.1816653597102453, 'q': 0.3369106689033968, 'dims': 256, 'walk_length': 27, 'num_walks': 50, 'window': 6, 'epochs': 5}. Best is trial 21 with value: 0.9638755961319057.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# D:\NLP\gnn_env\lib\site-packages\joblib\externals\loky\process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [I 2025-05-16 14:17:49,022] Trial 23 finished with value: 0.962034429902875 and parameters: {'p': 1.4224836636752924, 'q': 0.46622183948794377, 'dims': 256, 'walk_length': 40, 'num_walks': 45, 'window': 5, 'epochs': 5}. Best is trial 21 with value: 0.9638755961319057.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 14:25:18,380] Trial 24 finished with value: 0.9602563386168863 and parameters: {'p': 0.8134355664539151, 'q': 0.2837467865096201, 'dims': 256, 'walk_length': 50, 'num_walks': 40, 'window': 8, 'epochs': 4}. Best is trial 21 with value: 0.9638755961319057.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 14:32:44,604] Trial 25 finished with value: 0.9629187394570204 and parameters: {'p': 2.0647371749304004, 'q': 0.4764887156968965, 'dims': 256, 'walk_length': 26, 'num_walks': 46, 'window': 6, 'epochs': 5}. Best is trial 21 with value: 0.9638755961319057.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 14:39:50,230] Trial 26 finished with value: 0.9623713255319495 and parameters: {'p': 3.2325678730815444, 'q': 0.6941073246502764, 'dims': 256, 'walk_length': 28, 'num_walks': 47, 'window': 6, 'epochs': 4}. Best is trial 21 with value: 0.9638755961319057.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 14:44:49,636] Trial 27 finished with value: 0.8595805179058981 and parameters: {'p': 2.3169733934499943, 'q': 0.47017230233110946, 'dims': 256, 'walk_length': 48, 'num_walks': 10, 'window': 8, 'epochs': 5}. Best is trial 21 with value: 0.9638755961319057.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 14:49:36,172] Trial 28 finished with value: 0.942764847445019 and parameters: {'p': 1.0989427549175592, 'q': 0.35249615345837404, 'dims': 128, 'walk_length': 62, 'num_walks': 38, 'window': 7, 'epochs': 3}. Best is trial 21 with value: 0.9638755961319057.
# D:\TMP\ipykernel_14948\3776485197.py:43: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   p      = trial.suggest_loguniform("p", 0.25, 4.0)
# D:\TMP\ipykernel_14948\3776485197.py:44: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   q      = trial.suggest_loguniform("q", 0.25, 4.0)
# [I 2025-05-16 14:54:57,175] Trial 29 finished with value: 0.9360958143176142 and parameters: {'p': 1.0103842260515166, 'q': 0.44419589065524245, 'dims': 64, 'walk_length': 37, 'num_walks': 43, 'window': 6, 'epochs': 5}. Best is trial 21 with value: 0.9638755961319057.
# Best AUC: 0.9638755961319057
# Best params: {'p': 1.340278589091097, 'q': 0.30263732679550054, 'dims': 256, 'walk_length': 23, 'num_walks': 44, 'window': 5, 'epochs': 5}
# Computing transition probabilities: 100%|████████████████████████████████████| 138499/138499 [01:06<00:00, 2096.69it/s]
# ✅ Saved tuned embeddings to D:/NLP/tfidf_xgboost/split_train_val/citation_node2vec_tuned.pkl
